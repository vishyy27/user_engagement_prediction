# %%
from database.feature_store import get_user_features, update_user_features

update_user_features("user_1", 75)

features = get_user_features("user_1")

print(features)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from database.feature_store import get_user_features, update_user_features
#       3 update_user_features("user_1", 75)
#       5 features = get_user_features("user_1")
#
# ImportError: cannot import name 'update_user_features' from 'database.feature_store' (C:\Users\dvish\User_Engagement_Prediction\database\feature_store.py)
