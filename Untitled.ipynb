# %%
from database.models import Base
from database.db import engine

Base.metadata.create_all(bind=engine)

print("✅ Tables recreated")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from database.models import Base
#       2 from database.db import engine
#       4 Base.metadata.create_all(bind=engine)
#
# File ~\User_Engagement_Prediction\database\models.py:3
#       1 from sqlalchemy import Column, Integer, Float, String, Text, TIMESTAMP, JSON
#       2 from sqlalchemy.sql import func
# ----> 3 from database.db import Base
#       6 #Users Table
#       7 class User(Base):
#
# File ~\User_Engagement_Prediction\database\db.py:13
#       6 engine = create_engine(
#       7     DATABASE_URL,
#       8     connect_args={"sslmode": "require"}
#       9 )
#      11 SessionLocal = sessionmaker(bind=engine)
# ---> 13 Base = declarative_base()
#      15 def get_connection():
#      16     return SessionLocal()
#
# NameError: name 'declarative_base' is not defined
