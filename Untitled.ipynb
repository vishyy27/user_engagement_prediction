# %%
from database.models import Base
from database.db import engine

Base.metadata.create_all(bind=engine)

print("✅ Tables recreated")
# Out:
# ✅ Tables recreated

# %%
from services.event_logger import log_event

log_event(
    "prediction_requested",
    "user_1",
    {"input": "test data"}
)

print("✅ Event logged")
# Out:
# ✅ Event logged

# %%
from services.event_logger import log_event

log_event("prediction_requested", "user_1", {"input": "test"})
log_event("high_engagement", "user_1")
log_event("low_engagement", "user_1")

print("✅ Events + Features Updated")
# Out:
# ✅ Events + Features Updated

# %%
from database.feature_store import get_user_features

features = get_user_features("user_1")
print(features)
# Out:
# {'avg_engagement_score': 75.0, 'total_predictions': 1, 'last_score': 75.0}

# %%
from services.event_logger import log_event

log_event("prediction_requested", "user_1")
log_event("high_engagement", "user_1")
log_event("low_engagement", "user_1")

# %%
from database.feature_store import get_user_features

print(get_user_features("user_1"))
# Out:
# {'avg_engagement_score': 75.0, 'total_predictions': 1, 'last_score': 75.0}

# %%
from services.event_logger import log_event

log_event("prediction_requested", "user_1")
log_event("high_engagement", "user_1")
log_event("low_engagement", "user_1")
# Out:
# Updating user: user_1
# Found user: <database.models.UserProfile object at 0x0000022EC7434CB0>
# Updating existing user
# Updating user: user_1
# Found user: <database.models.UserProfile object at 0x0000022EC7435820>
# Updating existing user
# Updating user: user_1
# Found user: <database.models.UserProfile object at 0x0000022EC74359D0>
# Updating existing user

# %%
from database.feature_store import get_user_features

print(get_user_features("user_1"))

# %%
from services.prediction_service import predict_user

result = predict_user({"user_id": "user_1"})
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 from services.prediction_service import predict_user
# ----> 3 result = predict_user({"user_id": "user_1"})
#       4 print(result)
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:18, in predict_user(data)
#      15 #Converting to DataFrame
#      16 df = pd.DataFrame([data_copy])
# ---> 18 df = df[[
#      19     "age",
#      20     "daily_active_time",
#      21     "posts_last_week",
#      22     "likes_last_week",
#      23     "activity_type",
#      24     "past_participation_rate",
#      25     "friends_participating",
#      26     "time_of_day",
#      27     "day_of_week"
#      28 ]]
#      30 #Prediction
#      31 score, engaged = predict(df)
#
# ...

# %%
result = predict_user({
    "user_id": "user_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": 1,
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": 2,
    "day_of_week": 3
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:1970, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1969     if not evt_handled:
# -> 1970         self.dialect.do_execute(
#    1971             cursor, str_statement, effective_parameters, context
#    1972         )
#    1974 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# ...

# %%
result = predict_user({
    "user_id": "user_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": 1,
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": 2,
    "day_of_week": 3
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:1970, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1969     if not evt_handled:
# -> 1970         self.dialect.do_execute(
#    1971             cursor, str_statement, effective_parameters, context
#    1972         )
#    1974 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# ...

# %%
result = predict_user({
    "user_id": "user_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": 1,
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": 2,
    "day_of_week": 3
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:1970, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1969     if not evt_handled:
# -> 1970         self.dialect.do_execute(
#    1971             cursor, str_statement, effective_parameters, context
#    1972         )
#    1974 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# ...

# %%
from services.prediction_service import predict_user

result = predict_user({
    "user_id": "user_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": 1,
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": 2,
    "day_of_week": 3
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from services.prediction_service import predict_user
# ----> 3 result = predict_user({
#       4     "user_id": "user_1",
#       5     "age": 22,
#       6     "daily_active_time": 60,
#       7     "posts_last_week": 3,
#       8     "likes_last_week": 10,
#       9     "activity_type": 1,
#      10     "past_participation_rate": 0.5,
#      11     "friends_participating": 4,
#      12     "time_of_day": 2,
#      13     "day_of_week": 3
#      14 })
#      16 print(result)
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:28, in predict_user(data)
#      14 df = pd.DataFrame([data_copy])
#      16 df = df[[
#      17     "age",
#      18     "daily_active_time",
#    (...)     25     "day_of_week"
#      26 ]]
# ---> 28 score, engaged = predict(df)
# ...

# %%
result = predict_user({
    "user_id": "user_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    
    # 🔥 FIX HERE
    "activity_type": "scroll",          # string
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": "evening",           # string
    "day_of_week": "weekday"            # string
})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = predict_user({
#       2     "user_id": "user_1",
#       3     "age": 22,
#       4     "daily_active_time": 60,
#       5     "posts_last_week": 3,
#       6     "likes_last_week": 10,
#       7
#       8     # 🔥 FIX HERE
#       9     "activity_type": "scroll",          # string
#      10     "past_participation_rate": 0.5,
#      11     "friends_participating": 4,
#      12     "time_of_day": "evening",           # string
#      13     "day_of_week": "weekday"            # string
#      14 })
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:30, in predict_user(data)
#      16 df = df[[
#      17     "age",
#      18     "daily_active_time",
#    (...)     25     "day_of_week"
#      26 ]]
#      28 score, engaged = predict(df)
# ...

# %%
from services.prediction_service import predict_user

result = predict_user({
    "user_id": "user_test_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": "scroll",
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": "evening",
    "day_of_week": "weekday"
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 from services.prediction_service import predict_user
# ----> 3 result = predict_user({
#       4     "user_id": "user_test_1",
#       5     "age": 22,
#       6     "daily_active_time": 60,
#       7     "posts_last_week": 3,
#       8     "likes_last_week": 10,
#       9     "activity_type": "scroll",
#      10     "past_participation_rate": 0.5,
#      11     "friends_participating": 4,
#      12     "time_of_day": "evening",
#      13     "day_of_week": "weekday"
#      14 })
#      16 print(result)
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:30, in predict_user(data)
#      16 df = df[[
#      17     "age",
#      18     "daily_active_time",
#    (...)     25     "day_of_week"
#      26 ]]
#      28 score, engaged = predict(df)
# ...

# %%
result = predict_user({...})
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = predict_user({...})
#       2 print(result)
#
# NameError: name 'predict_user' is not defined

# %%
from services.prediction_service import predict_user

# %%
result = predict_user({...})
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = predict_user({...})
#       2 print(result)
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:10, in predict_user(data)
#       9 def predict_user(data):
# ---> 10     user_id = data.get("user_id")
#      12     data_copy = data.copy()
#      13     data_copy.pop("user_id", None)
#
# AttributeError: 'set' object has no attribute 'get'

# %%
result = predict_user({
    "user_id": "user_test_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": "scroll",
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": "evening",
    "day_of_week": "weekday"
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = predict_user({
#       2     "user_id": "user_test_1",
#       3     "age": 22,
#       4     "daily_active_time": 60,
#       5     "posts_last_week": 3,
#       6     "likes_last_week": 10,
#       7     "activity_type": "scroll",
#       8     "past_participation_rate": 0.5,
#       9     "friends_participating": 4,
#      10     "time_of_day": "evening",
#      11     "day_of_week": "weekday"
#      12 })
#      14 print(result)
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:34, in predict_user(data)
#      31 update_user_profile(user_id, score)
#      33 reason = generate_reason(data)
# ---> 34 suggestion = generate_suggestion(data, score, user_id)
#      36 db = get_connection()
#      38 new_prediction = Prediction(
#      39     user_id=user_id,
# ...

# %%
result = predict_user({...})
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = predict_user({...})
#       2 print(result)
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:10, in predict_user(data)
#       9 def predict_user(data):
# ---> 10     user_id = data.get("user_id")
#      12     data_copy = data.copy()
#      13     data_copy.pop("user_id", None)
#
# AttributeError: 'set' object has no attribute 'get'

# %%
result = predict_user({
    "user_id": "user_test_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": "scroll",
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": "evening",
    "day_of_week": "weekday"
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result = predict_user({
#       2     "user_id": "user_test_1",
#       3     "age": 22,
#       4     "daily_active_time": 60,
#       5     "posts_last_week": 3,
#       6     "likes_last_week": 10,
#       7     "activity_type": "scroll",
#       8     "past_participation_rate": 0.5,
#       9     "friends_participating": 4,
#      10     "time_of_day": "evening",
#      11     "day_of_week": "weekday"
#      12 })
#      14 print(result)
#
# File ~\User_Engagement_Prediction\services\prediction_service.py:34, in predict_user(data)
#      31 update_user_profile(user_id, score)
#      33 reason = generate_reason(data)
# ---> 34 suggestion = generate_suggestion(data, score, user_id)
#      36 db = get_connection()
#      38 new_prediction = Prediction(
#      39     user_id=user_id,
# ...

# %%
from services.prediction_service import predict_user

# %%
result = predict_user({
    "user_id": "user_test_1",
    "age": 22,
    "daily_active_time": 60,
    "posts_last_week": 3,
    "likes_last_week": 10,
    "activity_type": "scroll",
    "past_participation_rate": 0.5,
    "friends_participating": 4,
    "time_of_day": "evening",
    "day_of_week": "weekday"
})

print(result)
# Out:
# {'user_id': 'user_test_1', 'engagement_score': 59, 'engaged': 1, 'reason': 'Good engagement behavior', 'suggestion': ''}
